# %%
import pandas as pd
import numpy as np
import glob
import electromagnetics as el
import plot_contour as pc
from global_variables import gparam
gl = gparam()

# %%
files = glob.glob('coils\*.csv')

# %%
for file in files:
    #file = 'coils\\cct2.csv'
    df = pd.read_csv(file)
    
    mat = np.zeros((gl.nz, gl.nr))
    for e in df.values:
        mat += np.array([[el.flux(r, z, e[0], e[1], 1) for r in gl.r_pos] for z in gl.z_pos])
        
    fi = file[6:-4]+'.npy'
    print(fi)
    np.save(fi, mat)
# Out:
# cct1.npy
# cct2.npy
# cct4.npy
# hclt16.npy
# hclt6.npy
# hcut16.npy
# hcut6.npy
# pf1t12.npy
# pf1t4.npy
# pf1t8.npy
# pf2t18.npy
# pf2t36.npy
# pf2t72.npy
# pf3_1.npy
# pf3_2.npy
# pf41.npy
# pf42a.npy
# pf42b.npy
# pf43.npy
# pf5_1.npy
# pf5_2.npy
# pf6t18.npy
# pf6t36.npy
# pf6t72.npy
# pf7t12.npy
# pf7t4.npy
# pf7t8.npy

# %%
pc.contour(mat, gl.r_min, gl.z_min, gl.del_r, gl.del_z)

# %%
dat = np.load('coils\\cct2.npy')

# %%
dat
# Out:
# array([[0.00000000e+00, 1.69815743e-10, 6.79250846e-10, ...,
#         4.01750632e-06, 4.04528755e-06, 4.07284707e-06],
#        [0.00000000e+00, 1.71128096e-10, 6.84500307e-10, ...,
#         4.05179960e-06, 4.07976926e-06, 4.10751269e-06],
#        [0.00000000e+00, 1.72448500e-10, 6.89781977e-10, ...,
#         4.08647285e-06, 4.11463282e-06, 4.14256196e-06],
#        ...,
#        [0.00000000e+00, 1.72448500e-10, 6.89781977e-10, ...,
#         4.08647285e-06, 4.11463282e-06, 4.14256196e-06],
#        [0.00000000e+00, 1.71128096e-10, 6.84500307e-10, ...,
#         4.05179960e-06, 4.07976926e-06, 4.10751269e-06],
#        [0.00000000e+00, 1.69815743e-10, 6.79250846e-10, ...,
#         4.01750632e-06, 4.04528755e-06, 4.07284707e-06]])
