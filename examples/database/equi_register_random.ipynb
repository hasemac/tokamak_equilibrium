# %% [markdown]
# # データベースに平衡計算の結果を登録

# %% [markdown]
# アクセス可能なデータベースを準備する必要があります。
# 計算結果を保存する場所を用意する必要があります。
# その上で、ルートディレクトリにある.env_exampleを参考に同じ場所に.envを作成して、使用するデータベース名やユーザー名などを記述してください。

# %%
# Setting
table_name='tf100ka'
comment = "check range of aspect_ratio"
# 計算結果を保存するディレクトリ
dir_store = '\\\\quest-db.riam.kyushu-u.ac.jp\\share\\equilibrium'

# %%
import os
os.chdir('../..')
import itertools
import random
import numpy as np
import copy
import sub.plot as pl
import sub.functions as sb
import sub.db as sdb
from global_variables import gparam
gl = gparam()

# %%
# ディレクトリの有無確認
dir = os.path.join(dir_store, table_name)
if not os.path.exists(dir):
    os.makedirs(dir)
    
# データベース設定
dbeq = sdb.DB_equilibrium()
dbeq.set_table(table_name, comment=comment)
chdat = sdb.DB(table_name)

# %%
# define fundamental condition
condition = {
    # TF current
    'cur_tf':{'tf': +100.0e+3, 'turn': 16},
    
    # initial plasma profile
    'cur_ip':{'ip':+100.0e+3, 'r0':0.65, 'z0':0.00, 'radius':0.3, 'degree': 2.0},
    
    # PF currents
    'cur_pf':{'pf17t12':-2.0e+3, 'pf26t36':-2.0e+3,'pf4_1ab3_cc2':-1.0e+3, 'pf35_1': 4.0e+3, 'pf35_2': 4.0e+3, },
        
    # number of coefficients
    'num_dpr':1, # dp/df
    'num_di2':1, # di2/df

    # flag to fix magnetic axis at initial plasma profile (r0, z0) 
    #'fix_pos': True,

    # calculate flux (r, z): result is set to 'fl_val'.
    # 'fl_pos':{'flc8':(0.1985, 0.450), 'f_im':(0.1985, 0.0), 'flc17':(0.1985, -0.450),
    #           'fls1':(1.374, 0.450), 'fls5':(1.374, 0.0), 'fls9':(1.374, -0.481)},
    # calculate Br(r, z): result is set to 'br_val'
    #'br_pos':{'r1000z0':(1.0, 1.0)},
    # calculate Bz(r, z): result is set to 'bz_val'
    'bz_pos':{'r0zp800':(0.0, 0.8), 'r0zp400':(0.0, 0.4), 'r0z0':(0.0, 0.0), 'r0zm400':(0.0, -0.4), 'r0zm800':(0.0, -0.8),
              'r1450zp400':(1.45, 0.4), 'r1450z0':(1.45, 0.0), 'r1450zm400':(1.45, -0.4), },
    
    'resolution': gl.get_dmat_coarse(),
    }

# %%
# define parameters to change

r0 = [0.5, 1.0]
pf17 = [-8.0, 0.0]
pf26 = [-8.0, 0.0]
pf4 =  [-8.0, 0.0]
pf351 = [0.0, 8.0]
pf352 = [0.0, 8.0]

pf17  = np.array(pf17) * 1.0e+3
pf26  = np.array(pf26) * 1.0e+3
pf4   = np.array(pf4) * 1.0e+3
pf351 = np.array(pf351) * 1.0e+3
pf352 = np.array(pf352) * 1.0e+3

# %%
num_calc = 50000

# Calculate equilibrium and regist the data
for e in range(num_calc):
   print('num:', e)
   cnd = copy.deepcopy(condition)
   cnd['cur_ip']['r0']         = random.uniform(*r0)
   cnd['cur_pf']['pf17t12']    = random.uniform(*pf17)
   cnd['cur_pf']['pf26t36']    = random.uniform(*pf26)
   cnd['cur_pf']['pf4_1ab3_cc2'] = random.uniform(*pf4)
   cnd['cur_pf']['pf35_1']     = random.uniform(*pf351)
   cnd['cur_pf']['pf35_2']     = random.uniform(*pf352)

   # 実際にデータベースへ登録をするときは、下を有効にする。   
   cnd = sb.calc_equilibrium(cnd, verbose=0)
   dat = sdb.disassemble_condition(cnd)
   # id = dbeq.get_next_id()
   dbeq.add_data(dat)
   # fdir = os.path.join(dir, f"{id}.npy")
   # np.save(fdir, cnd)
# Out:
# num: 0
# num: 1
# num: 2
# num: 3
# num: 4
# num: 5
# num: 6
# num: 7
# num: 8
# num: 9
# num: 10
# num: 11
# num: 12
# num: 13
# Calculation doesn't converge.
#
# num: 14
# Negtive pressure found.
#
# num: 15
# num: 16
# num: 17
# num: 18
# num: 19
# Calculation doesn't converge.
#
# num: 20
# num: 21
# num: 22
# Calculation doesn't converge.
#
# num: 23
# num: 24
# num: 25
# num: 26
# num: 27
# num: 28
# num: 29
# num: 30
# num: 31
# num: 32
# num: 33
# num: 34
# num: 35
# num: 36
# num: 37
# num: 38
# num: 39
# num: 40
# num: 41
# num: 42
# num: 43
# num: 44
# num: 45
# num: 46
# Negtive pressure found.
#
# num: 47
# num: 48
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 49
# num: 50
# num: 51
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 52
# num: 53
# num: 54
# num: 55
# Calculation doesn't converge.
#
# num: 56
# num: 57
# Negtive pressure found.
#
# num: 58
# num: 59
# num: 60
# num: 61
# num: 62
# num: 63
# num: 64
# num: 65
# num: 66
# num: 67
# num: 68
# num: 69
# num: 70
# num: 71
# num: 72
# num: 73
# num: 74
# num: 75
# num: 76
# num: 77
# num: 78
# num: 79
# num: 80
# num: 81
# Calculation doesn't converge.
#
# num: 82
# Negtive pressure found.
#
# num: 83
# num: 84
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 85
# Calculation doesn't converge.
#
# num: 86
# num: 87
# num: 88
# num: 89
# Calculation doesn't converge.
#
# num: 90
# num: 91
# num: 92
# num: 93
# num: 94
# num: 95
# num: 96
# num: 97
# num: 98
# Negtive pressure found.
#
# num: 99
# num: 100
# num: 101
# num: 102
# num: 103
# num: 104
# num: 105
# num: 106
# num: 107
# num: 108
# num: 109
# num: 110
# num: 111
# num: 112
# Calculation doesn't converge.
#
# num: 113
# num: 114
# Negtive pressure found.
#
# num: 115
# num: 116
# num: 117
# Calculation doesn't converge.
#
# num: 118
# num: 119
# Negtive pressure found.
#
# num: 120
# num: 121
# num: 122
# num: 123
# Calculation doesn't converge.
#
# num: 124
# num: 125
# Calculation doesn't converge.
#
# num: 126
# num: 127
# num: 128
# num: 129
# Calculation doesn't converge.
#
# num: 130
# num: 131
# Negtive pressure found.
#
# num: 132
# num: 133
# Negtive pressure found.
#
# num: 134
# Negtive pressure found.
#
# num: 135
# num: 136
# num: 137
# num: 138
# num: 139
# num: 140
# num: 141
# num: 142
# num: 143
# Calculation doesn't converge.
# Negtive pressure found.
#
# num:
# num: 724
# num: 725
# Negtive pressure found.
#
# num: 726
# Calculation doesn't converge.
#
# num: 727
# num: 728
# num: 729
# Negtive pressure found.
#
# num: 730
# num: 731
# num: 732
# num: 733
# num: 734
# num: 735
# num: 736
# num: 737
# num: 738
# num: 739
# num: 740
# Calculation doesn't converge.
#
# num: 741
# num: 742
# num: 743
# num: 744
# num: 745
# num: 746
# num: 747
# num: 748
# num: 749
# num: 750
# num: 751
# num: 752
# num: 753
# num: 754
# num: 755
# Calculation doesn't converge.
#
# num: 756
# num: 757
# num: 758
# num: 759
# num: 760
# num: 761
# Negtive pressure found.
#
# num: 762
# num: 763
# num: 764
# Negtive pressure found.
#
# num: 765
# num: 766
# num: 767
# Calculation doesn't converge.
#
# num: 768
# num: 769
# num: 770
# num: 771
# Calculation doesn't converge.
#
# num: 772
# num: 773
# num: 774
# Negtive pressure found.
#
# num: 775
# num: 776
# Negtive pressure found.
#
# num: 777
# num: 778
# num: 779
# Calculation doesn't converge.
#
# num: 780
# num: 781
# num: 782
# num: 783
# num: 784
# num: 785
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 786
# num: 787
# num: 788
# num: 789
# num: 790
# num: 791
# num: 792
# num: 793
# num: 794
# num: 795
# num: 796
# num: 797
# num: 798
# num: 799
# num: 800
# num: 801
# Calculation doesn't converge.
#
# num: 802
# Calculation doesn't converge.
#
# num: 803
# Negtive pressure found.
#
# num: 804
# num: 805
# Negtive pressure found.
#
# num: 806
# num: 807
# num: 808
# Calculation doesn't converge.
#
# num: 809
# num: 810
# num: 811
# num: 812
# num: 813
# num: 814
# num: 815
# num: 816
# num: 817
# num: 818
# num: 819
# Negtive pressure found.
#
# num: 820
# num: 821
# num: 822
# num: 823
# num: 824
# num: 825
# num: 826
# Negtive pressure found.
#
# num: 827
# Negtive pressure found.
#
# num: 828
# num: 829
# num: 830
# num: 831
# num: 832
# num: 833
# num: 834
# num: 835
# num: 836
# num: 837
# num: 838
# num: 839
# num: 840
# num: 841
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 842
# num: 843
# num: 844
# num: 845
# num: 846
# Calculation doesn't converge.
#
# num: 847
# Calculation doesn't converge.
#
# num: 848
# Negtive pressure found.
#
# num: 849
# num: 850
# num: 851
# num: 852
# Calculation doesn't converge.
#
# num: 853
# Calculation doesn't converge.
#
# num: 854
# num: 855
# num: 856
# num: 857
# num: 858
# num: 859
# num: 860
# num: 861
# num: 862
# num: 863
# num: 864
# num: 865
# num: 866
# num: 867
# num: 868
# Calculation doesn't converge.
#
# num: 869
# num: 870
# num: 871
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 872
# num: 873
# num: 874
# num: 875
# num: 876
# Calculation doesn't converge.
#
# num: 877
# num: 878
# num: 879
# num: 880
# Calculation doesn't converge.
#
# num: 881
# num: 882
# num: 883
# Calculation doesn't converge.
#
# num: 884
# num: 885
# num: 886
# Negtive pressure found.
#
# num: 887
# num: 888
# num: 889
# num: 890
# num: 891
# Negtive pressure found.
#
# num: 892
# Calculation doesn't converge.
#
# num: 893
# num: 894
# num: 895
# num: 896
# num: 897
# num: 898
# Negtive pressure found.
#
# num: 899
# num: 900
# num: 901
# Calculation doesn't converge.
#
# num: 902
# num: 903
# num: 904
# num: 905
# num: 906
# num: 907
# num: 908
# num: 909
# num: 910
# Negtive pressure found.
#
# num: 911
# num: 912
# num: 913
# num: 914
# num: 915
# num: 916
# num: 917
# num: 918
# num: 919
# Calculation doesn't converge.
#
# num: 920
# Calculation doesn't converge.
#
# num: 921
# Negtive pressure found.
#
# num: 922
# num: 923
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 924
# Calculation doesn't converge.
#
# num: 925
# Calculation doesn't converge.
#
# num: 926
# num: 927
# num: 928
# num: 929
# num: 930
# Calculation doesn't converge.
#
# num: 931
# num: 932
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 933
# num: 934
# num: 935
# Negtive pressure found.
#
# num: 936
# num: 937
# num: 938
# num: 939
# num: 940
# num: 941
# num: 942
# num: 943
# num: 944
# num: 945
# Negtive pressure found.
#
# num: 946
# num: 947
# num: 948
# num: 949
# Negtive pressure found.
#
# num: 950
# num: 951
# num: 952
# num: 953
# num: 954
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 955
# num: 956
# num: 957
# Calculation doesn't converge.
#
# num: 958
# num: 959
# num: 960
# num: 961
# num: 962
# num: 963
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 964
# Calculation doesn't converge.
#
# num: 965
# num: 966
# num: 967
# Negtive pressure found.
#
# num: 968
# num: 969
# num: 970
# num: 971
# num: 972
# Negtive pressure found.
#
# num: 973
# num: 974
# num: 975
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 976
# num: 977
# num: 978
# Calculation doesn't converge.
#
# num: 979
# num: 980
# num: 981
# num: 982
# num: 983
# num: 984
# Negtive pressure found.
#
# num: 985
# num: 986
# num: 987
# num: 988
# num: 989
# num: 990
# Negtive pressure found.
#
# num: 991
# num: 992
# num: 993
# num: 994
# num: 995
# num: 996
# Calculation doesn't converge.
#
# num: 997
# Negtive pressure found.
#
# num: 998
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 999
# num: 1000
# num: 1001
# num: 1002
# num: 1003
# num: 1004
# num: 1005
# Calculation doesn't converge.
#
# num: 1006
# num: 1007
# num: 1008
# num: 1009
# Calculation doesn't converge.
#
# num: 1010
# num: 1011
# num: 1012
# num: 1013
# num: 1014
# num: 1015
# num: 1016
# num: 1017
# num: 1018
# num: 1019
# num: 1020
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1021
# num: 1022
# num: 1023
# num: 1024
# num: 1025
# num: 1026
# num: 1027
# num: 1028
# num: 1029
# num: 1030
# num: 1031
# num: 1032
# num: 1033
# num: 1034
# num: 1035
# num: 1036
# num: 1037
# Calculation doesn't converge.
#
# num: 1038
# num: 1039
# num: 1040
# Calculation doesn't converge.
#
# num: 1041
# num: 1042
# num: 1043
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1044
# Negtive pressure found.
#
# num: 1045
# num: 1046
# Calculation doesn't converge.
#
# num: 1047
# num: 1048
# num: 1049
# num: 1050
# Negtive pressure found.
#
# num: 1051
# num: 1052
# num: 1053
# num: 1054
# num: 1055
# num: 1056
# Negtive pressure found.
#
# num: 1057
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1058
# num: 1059
# num: 1060
# num: 1061
# num: 1062
# num: 1063
# num: 1064
# num: 1065
# num: 1066
# num: 1067
# Negtive pressure found.
#
# num: 1068
# num: 1069
# num: 1070
# Negtive pressure found.
#
# num: 1071
# Calculation doesn't converge.
#
# num: 1072
# num: 1073
# num: 1074
# num: 1075
# num: 1076
# num: 1077
# num: 1078
# num: 1079
# Negtive pressure found.
#
# num: 1080
# num: 1081
# num: 1082
# num: 1083
# num: 1084
# num: 1085
# num: 1086
# num: 1087
# num: 1088
# num: 1089
# num: 1090
# Negtive pressure found.
#
# num: 1091
# num: 1092
# Calculation doesn't converge.
#
# num: 1093
# num: 1094
# num: 1095
# num: 1096
# num: 1097
# num: 1098
# Calculation doesn't converge.
#
# num: 1099
# Calculation doesn't converge.
#
# num: 1100
# num: 1101
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1102
# num: 1103
# Calculation doesn't converge.
#
# num: 1104
# Calculation doesn't converge.
#
# num: 1105
# num: 1106
# Calculation doesn't converge.
#
# num: 1107
# num: 1108
# num: 1109
# num: 1110
# num: 1111
# Negtive pressure found.
#
# num: 1112
# num: 1113
# num: 1114
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1115
# num: 1116
# num: 1117
# num: 1118
# num: 1119
# Negtive pressure found.
#
# num: 1120
# num: 1121
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1122
# num: 1123
# Negtive pressure found.
#
# num: 1124
# num: 1125
# num: 1126
# num: 1127
# Calculation doesn't converge.
#
# num: 1128
# num: 1129
# num: 1130
# num: 1131
# num: 1132
# num: 1133
# num: 1134
# num: 1135
# num: 1136
# num: 1137
# Negtive pressure found.
#
# num: 1138
# num: 1139
# num: 1140
# num: 1141
# num: 1142
# Negtive pressure found.
#
# num: 1143
# num: 1144
# num: 1145
# num: 1146
# num: 1147
# num: 1148
# num: 1149
# num: 1150
# num: 1151
# num: 1152
# Calculation doesn't converge.
#
# num: 1153
# num: 1154
# num: 1155
# num: 1156
# num: 1157
# num: 1158
# num: 1159
# num: 1160
# num: 1161
# num: 1162
# num: 1163
# num: 1164
# num: 1165
# num: 1166
# num: 1167
# Calculation doesn't converge.
#
# num: 1168
# Calculation doesn't converge.
#
# num: 1169
# num: 1170
# num: 1171
# Calculation doesn't converge.
#
# num: 1172
# num: 1173
# num: 1174
# num: 1175
# Calculation doesn't converge.
#
# num: 1176
# num: 1177
# num: 1178
# num: 1179
# num: 1180
# num: 1181
# num: 1182
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1183
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1184
# num: 1185
# num: 1186
# num: 1187
# num: 1188
# Calculation doesn't converge.
#
# num: 1189
# num: 1190
# num: 1191
# num: 1192
# num: 1193
# num: 1194
# Calculation doesn't converge.
#
# num: 1195
# Negtive pressure found.
#
# num: 1196
# num: 1197
# Negtive pressure found.
#
# num: 1198
# num: 1199
# num: 1200
# num: 1201
# num: 1202
# num: 1203
# num: 1204
# num: 1205
# num: 1206
# Calculation doesn't converge.
#
# num: 1207
# Negtive pressure found.
#
# num: 1208
# num: 1209
# num: 1210
# num: 1211
# Calculation doesn't converge.
#
# num: 1212
# num: 1213
# num: 1214
# num: 1215
# num: 1216
# num: 1217
# num: 1218
# num: 1219
# num: 1220
# num: 1221
# num: 1222
# Calculation doesn't converge.
#
# num: 1223
# num: 1224
# Calculation doesn't converge.
#
# num: 1225
# num: 1226
# num: 1227
# Calculation doesn't converge.
#
# num: 1228
# Calculation doesn't converge.
#
# num: 1229
# num: 1230
# Calculation doesn't converge.
#
# num: 1231
# num: 1232
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1233
# num: 1234
# num: 1235
# num: 1236
# Calculation doesn't converge.
#
# num: 1237
# num: 1238
# num: 1239
# num: 1240
# num: 1241
# num: 1242
# num: 1243
# num: 1244
# num: 1245
# Calculation doesn't converge.
#
# num: 1246
# Calculation doesn't converge.
#
# num: 1247
# num: 1248
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1249
# num: 1250
# num: 1251
# num: 1252
# num: 1253
# Calculation doesn't converge.
#
# num: 1254
# num: 1255
# num: 1256
# Calculation doesn't converge.
#
# num: 1257
# num: 1258
# num: 1259
# num: 1260
# num: 1261
# num: 1262
# num: 1263
# Calculation doesn't converge.
#
# num: 1264
# Calculation doesn't converge.
#
# num: 1265
# Negtive pressure found.
#
# num: 1266
# num: 1267
# num: 1268
# num: 1269
# num: 1270
# num: 1271
# Negtive pressure found.
#
# num: 1272
# num: 1273
# num: 1274
# Calculation doesn't converge.
#
# num: 1275
# num: 1276
# num: 1277
# num: 1278
# num: 1279
# num: 1280
# num: 1281
# Calculation doesn't converge.
#
# num: 1282
# num: 1283
# Negtive pressure found.
#
# num: 1284
# Calculation doesn't converge.
#
# num: 1285
# num: 1286
# num: 1287
# num: 1288
# num: 1289
# Negtive pressure found.
#
# num: 1290
# num: 1291
# num: 1292
# num: 1293
# num: 1294
# num: 1295
# num: 1296
# num: 1297
# num: 1298
# num: 1299
# Negtive pressure found.
#
# num: 1300
# num: 1301
# Calculation doesn't converge.
#
# num: 1302
# Negtive pressure found.
#
# num: 1303
# num: 1304
# num: 1305
# num: 1306
# num: 1307
# Negtive pressure found.
#
# num: 1308
# num: 1309
# Calculation doesn't converge.
#
# num: 1310
# num: 1311
# Calculation doesn't converge.
#
# num: 1312
# Negtive pressure found.
#
# num: 1313
# Calculation doesn't converge.
#
# num: 1314
# num: 1315
# num: 1316
# num: 1317
# num: 1318
# num: 1319
# num: 1320
# num: 1321
# num: 1322
# num: 1323
# num: 1324
# num: 1325
# Calculation doesn't converge.
#
# num: 1326
# num: 1327
# num: 1328
# num: 1329
# num: 1330
# num: 1331
# num: 1332
# Negtive pressure found.
#
# num: 1333
# num: 1334
# num: 1335
# num: 1336
# Calculation doesn't converge.
#
# num: 1337
# Negtive pressure found.
#
# num: 1338
# num: 1339
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1340
# num: 1341
# num: 1342
# Calculation doesn't converge.
#
# num: 1343
# Negtive pressure found.
#
# num: 1344
# Calculation doesn't converge.
#
# num: 1345
# num: 1346
# num: 1347
# num: 1348
# num: 1349
# num: 1350
# num: 1351
# num: 1352
# num: 1353
# num: 1354
# num: 1355
# num: 1356
# num: 1357
# num: 1358
# num: 1359
# num: 1360
# num: 1361
# num: 1362
# num: 1363
# num: 1364
# num: 1365
# num: 1366
# num: 1367
# num: 1368
# num: 1369
# num: 1370
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1371
# num: 1372
# num: 1373
# num: 1374
# num: 1375
# num: 1376
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1377
# num: 1378
# Calculation doesn't converge.
#
# num: 1379
# num: 1380
# Negtive pressure found.
#
# num: 1381
# num: 1382
# num: 1383
# num: 1384
# num: 1385
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1386
# num: 1387
# num: 1388
# num: 1389
# num: 1390
# num: 1391
# Negtive pressure found.
#
# num: 1392
# num: 1393
# num: 1394
# num: 1395
# num: 1396
# Calculation doesn't converge.
#
# num: 1397
# num: 1398
# Negtive pressure found.
#
# num: 1399
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1400
# Calculation doesn't converge.
#
# num: 1401
# num: 1402
# num: 1403
# num: 1404
# Calculation doesn't converge.
#
# num: 1405
# num: 1406
# num: 1407
# num: 1408
# num: 1409
# num: 1410
# num: 1411
# num: 1412
# num: 1413
# num: 1414
# num: 1415
# num: 1416
# Calculation doesn't converge.
#
# num: 1417
# num: 1418
# num: 1419
# num: 1420
# Calculation doesn't converge.
#
# num: 1421
# num: 1422
# num: 1423
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1424
# num: 1425
# Negtive pressure found.
#
# num: 1426
# num: 1427
# num: 1428
# num: 1429
# num: 1430
# Negtive pressure found.
#
# num: 1431
# num: 1432
# num: 1433
# Negtive pressure found.
#
# num: 1434
# Calculation doesn't converge.
#
# num: 1435
# Negtive pressure found.
#
# num: 1436
# num: 1437
# Calculation doesn't converge.
#
# num: 1438
# Calculation doesn't converge.
#
# num: 1439
# num: 1440
# num: 1441
# num: 1442
# num: 1443
# num: 1444
# num: 1445
# num: 1446
# num: 1447
# num: 1448
# num: 1449
# num: 1450
# num: 1451
# num: 1452
# num: 1453
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1454
# num: 1455
# Negtive pressure found.
#
# num: 1456
# num: 1457
# num: 1458
# num: 1459
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1460
# num: 1461
# num: 1462
# num: 1463
# num: 1464
# num: 1465
# num: 1466
# num: 1467
# num: 1468
# num: 1469
# num: 1470
# Negtive pressure found.
#
# num: 1471
# num: 1472
# num: 1473
# num: 1474
# num: 1475
# Negtive pressure found.
#
# num: 1476
# Negtive pressure found.
#
# num: 1477
# num: 1478
# num: 1479
# num: 1480
# num: 1481
# Calculation doesn't converge.
#
# num: 1482
# num: 1483
# num: 1484
# num: 1485
# num: 1486
# num: 1487
# num: 1488
# num: 1489
# num: 1490
# num: 1491
# num: 1492
# num: 1493
# num: 1494
# num: 1495
# Negtive pressure found.
#
# num: 1496
# num: 1497
# num: 1498
# num: 1499
# num: 1500
# num: 1501
# Calculation doesn't converge.
#
# num: 1502
# num: 1503
# Calculation doesn't converge.
#
# num: 1504
# num: 1505
# num: 1506
# num: 1507
# num: 1508
# num: 1509
# num: 1510
# num: 1511
# num: 1512
# num: 1513
# num: 1514
# num: 1515
# num: 1516
# num: 1517
# num: 1518
# num: 1519
# num: 1520
# Calculation doesn't converge.
#
# num: 1521
# num: 1522
# num: 1523
# num: 1524
# num: 1525
# num: 1526
# num: 1527
# num: 1528
# num: 1529
# num: 1530
# num: 1531
# Negtive pressure found.
#
# num: 1532
# num: 1533
# num: 1534
# num: 1535
# Calculation doesn't converge.
#
# num: 1536
# num: 1537
# num: 1538
# Negtive pressure found.
#
# num: 1539
# Negtive pressure found.
#
# num: 1540
# num: 1541
# num: 1542
# num: 1543
# num: 1544
# num: 1545
# num: 1546
# num: 1547
# Negtive pressure found.
#
# num: 1548
# num: 1549
# num: 1550
# num: 1551
# num: 1552
# num: 1553
# num: 1554
# num: 1555
# Negtive pressure found.
#
# num: 1556
# num: 1557
# num: 1558
# num: 1559
# Calculation doesn't converge.
#
# num: 1560
# num: 1561
# num: 1562
# num: 1563
# num: 1564
# num: 1565
# num: 1566
# num: 1567
# num: 1568
# num: 1569
# num: 1570
# num: 1571
# num: 1572
# num: 1573
# num: 1574
# num: 1575
# num: 1576
# num: 1577
# num: 1578
# num: 1579
# num: 1580
# num: 1581
# num: 1582
# num: 1583
# Negtive pressure found.
#
# num: 1584
# num: 1585
# num: 1586
# num: 1587
# num: 1588
# num: 1589
# num: 1590
# num: 1591
# num: 1592
# num: 1593
# num: 1594
# num: 1595
# num: 1596
# num: 1597
# num: 1598
# num: 1599
# num: 1600
# Calculation doesn't converge.
#
# num: 1601
# num: 1602
# num: 1603
# num: 1604
# Calculation doesn't converge.
#
# num: 1605
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1606
# num: 1607
# num: 1608
# num: 1609
# num: 1610
# num: 1611
# num: 1612
# num: 1613
# num: 1614
# Calculation doesn't converge.
#
# num: 1615
# num: 1616
# num: 1617
# num: 1618
# num: 1619
# num: 1620
# num: 1621
# num: 1622
# Calculation doesn't converge.
#
# num: 1623
# num: 1624
# num: 1625
# num: 1626
# num: 1627
# Calculation doesn't converge.
#
# num: 1628
# num: 1629
# num: 1630
# Calculation doesn't converge.
#
# num: 1631
# num: 1632
# Calculation doesn't converge.
#
# num: 1633
# num: 1634
# num: 1635
# num: 1636
# num: 1637
# num: 1638
# num: 1639
# num: 1640
# Calculation doesn't converge.
#
# num: 1641
# num: 1642
# num: 1643
# num: 1644
# num: 1645
# num: 1646
# num: 1647
# num: 1648
# num: 1649
# Negtive pressure found.
#
# num: 1650
# num: 1651
# num: 1652
# num: 1653
# num: 1654
# num: 1655
# num: 1656
# num: 1657
# num: 1658
# num: 1659
# num: 1660
# num: 1661
# num: 1662
# num: 1663
# num: 1664
# num: 1665
# num: 1666
# Negtive pressure found.
#
# num: 1667
# num: 1668
# num: 1669
# num: 1670
# num: 1671
# num: 1672
# Calculation doesn't converge.
#
# num: 1673
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1674
# num: 1675
# num: 1676
# num: 1677
# num: 1678
# num: 1679
# num: 1680
# num: 1681
# num: 1682
# num: 1683
# Calculation doesn't converge.
#
# num: 1684
# num: 1685
# num: 1686
# num: 1687
# num: 1688
# num: 1689
# Negtive pressure found.
#
# num: 1690
# num: 1691
# Calculation doesn't converge.
#
# num: 1692
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1693
# num: 1694
# num: 1695
# Calculation doesn't converge.
#
# num: 1696
# num: 1697
# num: 1698
# num: 1699
# num: 1700
# Negtive pressure found.
#
# num: 1701
# num: 1702
# num: 1703
# num: 1704
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1705
# num: 1706
# Calculation doesn't converge.
#
# num: 1707
# num: 1708
# num: 1709
# num: 1710
# Negtive pressure found.
#
# num: 1711
# num: 1712
# num: 1713
# num: 1714
# Calculation doesn't converge.
#
# num: 1715
# num: 1716
# num: 1717
# num: 1718
# num: 1719
# num: 1720
# num: 1721
# num: 1722
# num: 1723
# num: 1724
# Calculation doesn't converge.
#
# num: 1725
# Calculation doesn't converge.
#
# num: 1726
# num: 1727
# num: 1728
# num: 1729
# Calculation doesn't converge.
#
# num: 1730
# num: 1731
# num: 1732
# Negtive pressure found.
#
# num: 1733
# num: 1734
# num: 1735
# num: 1736
# num: 1737
# Negtive pressure found.
#
# num: 1738
# num: 1739
# num: 1740
# num: 1741
# num: 1742
# Negtive pressure found.
#
# num: 1743
# num: 1744
# num: 1745
# Calculation doesn't converge.
#
# num: 1746
# num: 1747
# num: 1748
# num: 1749
# num: 1750
# num: 1751
# num: 1752
# num: 1753
# num: 1754
# num: 1755
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1756
# num: 1757
# num: 1758
# num: 1759
# num: 1760
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1761
# num: 1762
# num: 1763
# num: 1764
# num: 1765
# Negtive pressure found.
#
# num: 1766
# num: 1767
# num: 1768
# num: 1769
# num: 1770
# num: 1771
# num: 1772
# num: 1773
# num: 1774
# num: 1775
# Calculation doesn't converge.
#
# num: 1776
# Calculation doesn't converge.
#
# num: 1777
# num: 1778
# Negtive pressure found.
#
# num: 1779
# num: 1780
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1781
# num: 1782
# num: 1783
# num: 1784
# num: 1785
# num: 1786
# num: 1787
# num: 1788
# num: 1789
# num: 1790
# num: 1791
# num: 1792
# num: 1793
# num: 1794
# num: 1795
# num: 1796
# num: 1797
# num: 1798
# num: 1799
# num: 1800
# num: 1801
# num: 1802
# Calculation doesn't converge.
#
# num: 1803
# num: 1804
# num: 1805
# Negtive pressure found.
#
# num: 1806
# num: 1807
# num: 1808
# num: 1809
# num: 1810
# num: 1811
# num: 1812
# Calculation doesn't converge.
#
# num: 1813
# num: 1814
# num: 1815
# num: 1816
# num: 1817
# num: 1818
# num: 1819
# num: 1820
# num: 1821
# num: 1822
# num: 1823
# Calculation doesn't converge.
#
# num: 1824
# num: 1825
# num: 1826
# num: 1827
# num: 1828
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1829
# num: 1830
# num: 1831
# Negtive pressure found.
#
# num: 1832
# num: 1833
# Calculation doesn't converge.
#
# num: 1834
# num: 1835
# num: 1836
# num: 1837
# num: 1838
# Calculation doesn't converge.
#
# num: 1839
# num: 1840
# num: 1841
# num: 1842
# num: 1843
# num: 1844
# Negtive pressure found.
#
# num: 1845
# num: 1846
# Calculation doesn't converge.
#
# num: 1847
# num: 1848
# num: 1849
# num: 1850
# num: 1851
# num: 1852
# num: 1853
# Negtive pressure found.
#
# num: 1854
# num: 1855
# num: 1856
# num: 1857
# num: 1858
# num: 1859
# num: 1860
# Calculation doesn't converge.
#
# num: 1861
# num: 1862
# num: 1863
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1864
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1865
# Negtive pressure found.
#
# num: 1866
# num: 1867
# num: 1868
# num: 1869
# num: 1870
# num: 1871
# num: 1872
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1873
# num: 1874
# num: 1875
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1876
# num: 1877
# num: 1878
# num: 1879
# num: 1880
# num: 1881
# num: 1882
# num: 1883
# num: 1884
# num: 1885
# num: 1886
# num: 1887
# num: 1888
# Calculation doesn't converge.
#
# num: 1889
# num: 1890
# num: 1891
# Calculation doesn't converge.
#
# num: 1892
# num: 1893
# num: 1894
# num: 1895
# num: 1896
# num: 1897
# num: 1898
# Calculation doesn't converge.
#
# num: 1899
# Calculation doesn't converge.
#
# num: 1900
# Negtive pressure found.
#
# num: 1901
# num: 1902
# num: 1903
# Calculation doesn't converge.
#
# num: 1904
# num: 1905
# num: 1906
# num: 1907
# num: 1908
# Calculation doesn't converge.
#
# num: 1909
# num: 1910
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1911
# num: 1912
# num: 1913
# num: 1914
# Negtive pressure found.
#
# num: 1915
# num: 1916
# Calculation doesn't converge.
#
# num: 1917
# num: 1918
# num: 1919
# num: 1920
# num: 1921
# Calculation doesn't converge.
#
# num: 1922
# num: 1923
# num: 1924
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1925
# num: 1926
# num: 1927
# Calculation doesn't converge.
#
# num: 1928
# num: 1929
# num: 1930
# num: 1931
# num: 1932
# num: 1933
# num: 1934
# num: 1935
# num: 1936
# num: 1937
# num: 1938
# num: 1939
# num: 1940
# Calculation doesn't converge.
#
# num: 1941
# num: 1942
# num: 1943
# num: 1944
# num: 1945
# Calculation doesn't converge.
#
# num: 1946
# num: 1947
# num: 1948
# num: 1949
# num: 1950
# num: 1951
# Calculation doesn't converge.
#
# num: 1952
# Negtive pressure found.
#
# num: 1953
# num: 1954
# num: 1955
# num: 1956
# num: 1957
# num: 1958
# Negtive pressure found.
#
# num: 1959
# num: 1960
# num: 1961
# num: 1962
# Negtive pressure found.
#
# num: 1963
# num: 1964
# num: 1965
# num: 1966
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1967
# num: 1968
# num: 1969
# num: 1970
# num: 1971
# num: 1972
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1973
# Calculation doesn't converge.
#
# num: 1974
# Calculation doesn't converge.
#
# num: 1975
# num: 1976
# Calculation doesn't converge.
#
# num: 1977
# num: 1978
# num: 1979
# num: 1980
# num: 1981
# num: 1982
# num: 1983
# num: 1984
# num: 1985
# Calculation doesn't converge.
#
# num: 1986
# Calculation doesn't converge.
#
# num: 1987
# Calculation doesn't converge.
#
# num: 1988
# num: 1989
# num: 1990
# num: 1991
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 1992
# num: 1993
# Calculation doesn't converge.
#
# num: 1994
# num: 1995
# num: 1996
# num: 1997
# num: 1998
# num: 1999
# Calculation doesn't converge.
#
# num: 2000
# Calculation doesn't converge.
#
# num: 2001
# num: 2002
# num: 2003
# num: 2004
# num: 2005
# num: 2006
# num: 2007
# num: 2008
# num: 2009
# num: 2010
# num: 2011
# num: 2012
# num: 2013
# num: 2014
# num: 2015
# num: 2016
# num: 2017
# Calculation doesn't converge.
#
# num: 2018
# num: 2019
# num: 2020
# num: 2021
# Calculation doesn't converge.
#
# num: 2022
# num: 2023
# num: 2024
# num: 2025
# num: 2026
# num: 2027
# num: 2028
# Calculation doesn't converge.
#
# num: 2029
# num: 2030
# num: 2031
# num: 2032
# num: 2033
# num: 2034
# num: 2035
# Negtive pressure found.
#
# num: 2036
# Calculation doesn't converge.
#
# num: 2037
# num: 2038
# num: 2039
# num: 2040
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2041
# num: 2042
# num: 2043
# Negtive pressure found.
#
# num: 2044
# num: 2045
# num: 2046
# num: 2047
# num: 2048
# num: 2049
# num: 2050
# num: 2051
# num: 2052
# Calculation doesn't converge.
#
# num: 2053
# num: 2054
# num: 2055
# num: 2056
# num: 2057
# num: 2058
# num: 2059
# num: 2060
# num: 2061
# Calculation doesn't converge.
#
# num: 2062
# num: 2063
# Calculation doesn't converge.
#
# num: 2064
# num: 2065
# num: 2066
# Calculation doesn't converge.
#
# num: 2067
# num: 2068
# num: 2069
# num: 2070
# Negtive pressure found.
#
# num: 2071
# num: 2072
# num: 2073
# Calculation doesn't converge.
#
# num: 2074
# num: 2075
# num: 2076
# num: 2077
# num: 2078
# num: 2079
# num: 2080
# num: 2081
# num: 2082
# num: 2083
# num: 2084
# Negtive pressure found.
#
# num: 2085
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2086
# num: 2087
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2088
# num: 2089
# num: 2090
# Calculation doesn't converge.
#
# num: 2091
# num: 2092
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2093
# num: 2094
# num: 2095
# num: 2096
# Negtive pressure found.
#
# num: 2097
# Negtive pressure found.
#
# num: 2098
# Negtive pressure found.
#
# num: 2099
# num: 2100
# num: 2101
# Negtive pressure found.
#
# num: 2102
# num: 2103
# Calculation doesn't converge.
#
# num: 2104
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2105
# num: 2106
# num: 2107
# num: 2108
# num: 2109
# num: 2110
# Calculation doesn't converge.
#
# num: 2111
# num: 2112
# num: 2113
# num: 2114
# num: 2115
# num: 2116
# num: 2117
# Calculation doesn't converge.
#
# num: 2118
# num: 2119
# num: 2120
# num: 2121
# num: 2122
# num: 2123
# num: 2124
# num: 2125
# num: 2126
# num: 2127
# num: 2128
# num: 2129
# num: 2130
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2131
# num: 2132
# num: 2133
# num: 2134
# num: 2135
# num: 2136
# num: 2137
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2138
# num: 2139
# num: 2140
# num: 2141
# num: 2142
# num: 2143
# Calculation doesn't converge.
#
# num: 2144
# num: 2145
# num: 2146
# num: 2147
# num: 2148
# Calculation doesn't converge.
#
# num: 2149
# Negtive pressure found.
#
# num: 2150
# num: 2151
# Calculation doesn't converge.
#
# num: 2152
# num: 2153
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2154
# num: 2155
# Calculation doesn't converge.
# Negtive pressure found.
#
# num: 2156
# num: 2157
# num: 2158
# num: 2159
# num: 2160
# num: 2161
# num: 2162
# num: 2163
# num: 2164
# num: 2165
# num: 2166
# num: 2167
# num: 2168
# num: 2169
# num: 2170
# num: 2171
# Calculation doesn't converge.
#
# num: 2172
# num: 2173
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\home\codes\tokamak_equilibrium\examples\database\equi_register_random.ipynb セル 8 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/c%3A/home/codes/tokamak_equilibrium/examples/database/equi_register_random.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> cnd['cur_pf']['pf35_2']     = random.uniform(*pf352)
#      <a href='vscode-notebook-cell:/c%3A/home/codes/tokamak_equilibrium/examples/database/equi_register_random.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> # 実際にデータベースへ登録をするときは、下を有効にする。
# ---> <a href='vscode-notebook-cell:/c%3A/home/codes/tokamak_equilibrium/examples/database/equi_register_random.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> cnd = sb.calc_equilibrium(cnd, verbose=0)
#      <a href='vscode-notebook-cell:/c%3A/home/codes/tokamak_equilibrium/examples/database/equi_register_random.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> dat = sdb.disassemble_condition(cnd)
#      <a href='vscode-notebook-cell:/c%3A/home/codes/tokamak_equilibrium/examples/database/equi_register_random.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a> # id = dbeq.get_next_id()
#
# File c:\home\codes\tokamak_equilibrium\sub\functions.py:1129, in calc_equilibrium(condition, iteration, verbose)
#    1125     return cond
#    1127 for i in range(iteration):
# -> 1129     cond = equi_calc_one_step(cond, verbose=verbose)
#    1130     if cond["cal_result"] == -1:
#    1131         return cond
#
# File c:\home\codes\tokamak_equilibrium\sub\functions.py:1085, in equi_calc_one_step(condition, verbose)
#    1081     cond["jt"] = dm_jt
#    1083 # プラズマ電流によるフラックス,br, bz
#    1084 # ここの箇所は計算時間がかかるので必要最小限に。
# -> 1085 cond["flux_jt"] = pmat.cal_plasma_flux(cond["jt"])
#    1086 # cond["br_jt"] = pmat_br.cal_plasma_br(cond["jt"])
#    1087 # cond["bz_jt"] = pmat_bz.cal_plasma_bz(cond["jt"])
#    1088
#    1089 # トータルのフラックス, br, bz
#    1090 cond["flux"] = emat.dm_add(cond["flux_jt"], cond["flux_coil"])
#
# File c:\home\codes\tokamak_equilibrium\plasma\pmat.py:66, in cal_plasma_flux(dmat)
#      64 dm["matrix"] = cflux(dm["matrix"])
#      65 r = emat.get_dmat_dim(dmat)
# ---> 66 r = emat.resampling(r, dm)
#      68 r['matrix'] *= r['dr']*r['dz'] # jtを電流密度とする場合
#      70 return r
#
# File c:\home\codes\tokamak_equilibrium\sub\emat.py:228, in resampling(d_mat0, d_mat1)
#     224 nz = int((zmax - zmin) / dz)
#     226 # nz, nr = d_mat1['matrix'].shape
# --> 228 mat = [
#     229     [linval2(rmin + i * dr, zmin + j * dz, d_mat1) for i in range(nr + 1)]
#     230     for j in range(nz + 1)
#     231 ]
#     232 d_mat0["matrix"] = np.array(mat)
#     233 return d_mat0
#
# File c:\home\codes\tokamak_equilibrium\sub\emat.py:229, in <listcomp>(.0)
#     224 nz = int((zmax - zmin) / dz)
#     226 # nz, nr = d_mat1['matrix'].shape
#     228 mat = [
# --> 229     [linval2(rmin + i * dr, zmin + j * dz, d_mat1) for i in range(nr + 1)]
#     230     for j in range(nz + 1)
#     231 ]
#     232 d_mat0["matrix"] = np.array(mat)
#     233 return d_mat0
#
# File c:\home\codes\tokamak_equilibrium\sub\emat.py:229, in <listcomp>(.0)
#     224 nz = int((zmax - zmin) / dz)
#     226 # nz, nr = d_mat1['matrix'].shape
#     228 mat = [
# --> 229     [linval2(rmin + i * dr, zmin + j * dz, d_mat1) for i in range(nr + 1)]
#     230     for j in range(nz + 1)
#     231 ]
#     232 d_mat0["matrix"] = np.array(mat)
#     233 return d_mat0
#
# File c:\home\codes\tokamak_equilibrium\sub\emat.py:139, in linval2(r, z, d_mat)
#     136 nz, nr = mat.shape
#     138 fr = (r - rmin) / dr  # [0,1)
# --> 139 ir = int(np.floor(fr))
#     140 fr -= ir
#     142 fz = (z - zmin) / dz  # [0, 1)
#
# KeyboardInterrupt:

# %%
# to read condition
#cnd = np.load(fdir, , allow_pickle=True).item()
