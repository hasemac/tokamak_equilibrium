# %%
import numpy as np
import plot as pl
import sub as sb
from global_variables import gparam
gl = gparam()

# %%
condition = {
    'cur_tf':50, 
    #'cur_ip':{'ip':-50, 'r0':0.7, 'z0':0.0, 'radius':0.3},
    #'cur_pf':{'hcult16':0.0,'pf26t18':1.0,'pf4_1ab3_cc2':0.0,'pf35_2':0.0,},
    #'cur_ip':{'ip':50, 'r0':0.5, 'z0':0.0, 'radius':0.3},
    #'cur_pf':{'hcult16':0.0,'pf26t18':-1.0,'pf4_1ab3_cc2':-1.0,'pf35_2':0.0,},
    'cur_ip':{'ip':-50, 'r0':0.60, 'z0':0.0, 'radius':0.3},
    'cur_pf':{'hcult16':0.0,'pf26t18':1.0,'pf4_1ab3_cc2':1.0,'pf35_2':-0.5, },        
    'num_dpr':2, # dp/dfの係数の個数
    'num_di2':2, # di2/dfの係数の個数
    'resolution': gl.get_dmat_coarse(),
    'error':[]
    }

# %%
cond = sb.calc_equilibrium(condition)
# Out:
# 0.23462808542334196
# 0.037901896926155546
# 0.019585562625117306
# 0.011500605443913448
# 0.011679957349666294

# %%
pl.d_contour(cond['jt'])

# %%
cond['beta_toroidal']
# Out:
# 0.9794775139194826

# %%
cond['pressure']['matrix'][55]
# Out:
# array([-0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  1.90526612e-05,  1.10319816e-04,
#         2.70188453e-04,  4.87320139e-04,  7.47850900e-04,  1.03702060e-03,
#         1.34053686e-03,  1.64558092e-03,  1.94143385e-03,  2.21975472e-03,
#         2.47457476e-03,  2.70208592e-03,  2.90030137e-03,  3.06865596e-03,
#         3.20760023e-03,  3.31822592e-03,  3.40194725e-03,  3.46025047e-03,
#         3.49451583e-03,  3.50590989e-03,  3.49534206e-03,  3.46347683e-03,
#         3.41079110e-03,  3.33766493e-03,  3.24449318e-03,  3.13180501e-03,
# ...

# %%
n = 10**18
k = 1.38*10**(-23)
t = 100*1.16*10**(4) # 10eV->(K)
n*k*t
# Out:
# 16.007999999999996
